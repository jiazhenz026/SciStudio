# %%
import pandas as pd

import scistudio

df = pd.DataFrame({"v": [1.0, 2.0, 3.0]})
alias = df

# %%
alias.loc[0, "v"] = 99.0

# %%
total = float(df.v.sum())

# %%
scistudio.output(total=total, table=df)
